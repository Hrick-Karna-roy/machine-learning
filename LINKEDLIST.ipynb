# %%
class node:
  def __init__(self,data):
    self.data = data
    self.next = next

class linkedlist:
  def __init__(self):
    self.head = None
    self.tail = None

  def printll(self):
    tempnode = self.head
    while(tempnode != None):
      print(tempnode.data)
      tempnode = tempnode.next

  def insert(self,data,pos = 0.1):
    tempnode = self.head
    newnode = node(data)
    newnode.next = None
    #print(newnode.next)
    count = 0
    if pos == 0.1:
      newnode.next = self.head
      #tempnode.next = newnode
      self.head = newnode
    elif pos == 0:
      while(tempnode.next != None):
        tempnode = tempnode.next
      tempnode.next = newnode
      newnode.next = None
      self.tail = newnode
    else:
      while(count < pos):
        count += 1
        tempnode = tempnode.next
      # print(tempnode)
      # print(tempnode.next)
      newnode.next = tempnode.next
      tempnode.next = newnode
    

  def delete(self,val):
    temp = self.head
    prev = None
    while(temp!=None):
      if temp.data == val:
        if prev == None:
          self.head = temp.next
          break
        else:
          prev.next = temp.next
      prev = temp
      temp = temp.next

ll = linkedlist()
n1 = node(5)
n2 = node(6)
ll.head = n1
ll.tail = n2
n1.next = n2
n2.next = None

# print(ll.head)
# print(ll.head.data)
# print(newnode)
# ll.printll()
ll.insert(7,0)
ll.printll()
ll.delete(6)
ll.printll()

print('How many element to enter: ')
num = int(input())
ll2 = linkedlist()
for i in range(num):
  val = int(input())
  n = node(val)
  if i == 0:
    ll2.head = n
    temp = ll2.head
  elif i == n-1:
    temp.next =
# Out:
# 5
# 6
# 7
# 5
# 7
